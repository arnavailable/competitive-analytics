# %%
import folium
import pandas as pd
import numpy as np

# %%
b313 = [34.073741999301504, -118.44387256392277]

# %%
starbucks = pd.read_csv('starbucks.csv')

# %%
usc = [34.022415, -118.285530]

# %%
# mid point of two latitudes and longitudes
# midpoint_lon = (starbucks.iloc[9, 7] + starbucks.iloc[36, 7]) / 2 
# midpoint_lat = (starbucks.iloc[9, 6] + starbucks.iloc[36, 6]) / 2
# b313 = [midpoint_lat - 0.0045, midpoint_lon - 0.0045]

# Draw a map with the center at the mean of the coordinates 34.073741999301504, -118.44387256392277
map = folium.Map(location=b313, zoom_start=13)
# Add a marker to the map
folium.Marker(b313, popup='UCLA Anderson B313').add_to(map)
# Add a circle to the map

# folium.Circle(b313, radius=5000, color='orange', fill=True, fill_color='orange').add_to(map)
# folium.Circle(b313, radius=6000, color='purple', fill=True, fill_color='purple').add_to(map)
# folium.Circle(b313, radius=7000, color='black', fill=True, fill_color='black').add_to(map)
# folium.Circle(b313, radius=8000, color='white', fill=True, fill_color='white').add_to(map)
# folium.Circle(b313, radius=9000, color='pink', fill=True, fill_color='pink').add_to(map)

folium.Circle(b313, radius=3218.68, color='red').add_to(map) #0.49
folium.Circle(b313, radius=8046.7, color='blue').add_to(map) #1.49
folium.Circle(b313, radius=16093.4, color='green').add_to(map) #2.99
# folium.Circle(b313, radius=24140.1, color='magenta').add_to(map) #5.99
# folium.Circle(b313, radius=32186.8, color='purple').add_to(map) #7.99


# # Add legend
# map.add_child(folium.ClickForMarker(popup='Restaurant'))

# #Add a legend to the map
# map.add_child(folium.LatLngPopup())

# # Add value to each concentric circle
# folium.Marker([34.073741999301504, -118.44387256392277], popup='1000m').add_to(map)

# Add a marker for each Starbucks location
for index, row in starbucks.iterrows():
    folium.Marker([row['lat'], row['lon']], popup=row['Location']).add_to(map)
# save map as png
# map.save('map1.png')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
map.save('map7.html')

# %%
map = folium.Map(location=b313, zoom_start=13)
# Add a marker to the map
folium.Marker(b313, popup='UCLA Anderson B313').add_to(map)
folium.Circle(b313, radius=3218.68, color='red').add_to(map) #0.49
#change start zoom of map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
map = folium.Map(location=b313, zoom_start=10)
# Add a marker to the map
folium.Marker(b313, popup='UCLA Anderson B313').add_to(map)
folium.Circle(b313, radius=3218.68, color='red').add_to(map) #0.49
folium.Circle(b313, radius=8046.7, color='blue').add_to(map) #1.49
folium.Circle(b313, radius=16093.4, color='green').add_to(map) #2.99
folium.Circle(b313, radius=24140.1, color='magenta').add_to(map) #5.99
folium.Circle(b313, radius=32186.8, color='purple').add_to(map) #7.99

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
folium.Circle(b313, radius=16093.4, color='green').add_to(map) #2.99
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
folium.Circle(b313, radius=24140.1, color='magenta').add_to(map) #5.99
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
folium.Circle(b313, radius=32186.8, color='purple').add_to(map) #7.99
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
starbucks.head(50)
# Out:
#     Num                            Location                 Address..1  \
# 0     1                  Olympic & Westwood        2215 Westwood Blvd.
# 1     2                      Pico & Midvale     10911 W Pico Boulevard
# 2     3                  Olympic & Sawtelle        11280 Olympic Blvd.
# 3     4                 Westwood & Missouri        1898 Westwood Blvd.
# 4     5              Santa Monica & Pontius    11155 Santa Monica Blvd
# 5     6                Westwood & Lindbrook         1161 Westwood Blvd
# 6     7             Ralphs Los Angeles #210       11727 W Olympic Blvd
# 7     8                Ralphs-Westwood #759          10861 Weyburn Ave
# 8     9                   Broxton & Weyburn         10955 West Weyburn
# 9    10                 Barrington & Sunset     11700 Barrington Court
# 10   11     Avenue of Stars & Constellation   1999 Avenue of the Stars
# 11   12   Century Park East & Constellation     1875 Century Park East
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 9
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# mid point of two latitudes and longitudes
midpoint_lon = (starbucks.iloc[9, 7] + starbucks.iloc[36, 7]) / 2 
midpoint_lat = (starbucks.iloc[9, 6] + starbucks.iloc[36, 6]) / 2
b313 = [midpoint_lat, midpoint_lon]

# %%
#plot midpoint
folium.Marker([midpoint_lat, midpoint_lon], popup='Midpoint').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
